# %%
import pandas as pd
import matplotlib.pyplot as plt

loss = pd.read_csv("loss.csv",index_col=0)

print("Min loss:",loss.min().values[0])
print("Min epoch:",loss.idxmin().values[0])
loss.plot()

plt.grid(True)d
plt.show()
# Out:
# Min loss: 1.1234816183775531
# Min epoch: 742
